# %%
import import_ipynb
# %run Utils.ipynb
# %run Models.ipynb

# %%
start_time = datetime.now()
print("Code running started at:", start_time.strftime("%Y-%m-%d %H:%M:%S"))
print_environment_info()
# Out:
# Code running started at: 2024-10-29 12:08:11
# ---------------------------------------
# Python Version: 3.9.19 | packaged by conda-forge | (main, Mar 20 2024, 12:38:46) [MSC v.1929 64 bit (AMD64)]
# Python Executable: c:\Users\Monet\anaconda3\envs\bone-age\python.exe
# Operating System: Windows 10
# Platform: Windows-10-10.0.19045-SP0
# Architecture: ('64bit', 'WindowsPE')
# NumPy Version: 1.26.4
# Pandas Version: 2.2.1
# TensorFlow Version: 2.7.0
# imblearn Version: 0.12.3
# Matplotlib Version: 3.8.3
# Current Working Directory: c:\Users\Monet\Desktop\EcoCurrentNet
# Installed Packages:
#
# Hardware Information:
#
# Software Versions:
# scikit-learn Version: 1.5.2
# scipy Version: 1.13.0
# Pillow Version: 10.3.0
# jupyter is not installed.
# seaborn Version: 0.13.2
# keras Version: 2.7.0
# matplotlib Version: 3.8.3
# numpy Version: 1.26.4
# tensorflow Version: 2.7.0
# imblearn is not installed.
# statsmodels is not installed.
# xgboost Version: 2.1.2
# lightgbm Version: 4.5.0
# catboost Version: 1.2.7
# optuna is not installed.
# tensorflow_addons Version: 0.22.0
# joblib Version: 1.3.2
# tqdm Version: 4.66.4

# %%
data_generator = OptoelectronicDataGenerator(n_samples=1000)
X_train, X_val, y_train, y_val, X, y = data_generator.preprocess_data()
print("Training data shape:", X_train.shape)
print("Validation data shape:", X_val.shape)
print("Training labels shape:", y_train.shape)
print("Validation labels shape:", y_val.shape)
# Out:
# Training data shape: (800, 12)
# Validation data shape: (200, 12)
# Training labels shape: (800,)
# Validation labels shape: (200,)

# %%
evaluate_models_and_optimizers(X_train, y_train, X_val, y_val)
# Out:
# ------------------------------------------------------
# Evaluating model: EcoCurrentNet_V1
#   Evaluating with optimizer: Adam
#
# Neural Network Metrics (ANN):
# Root Mean Square Error: 465116.955059
# Mean Squared Error: 216333781883.049377
# Mean Absolute Error: 398039.882654
# R² Score: -2.723489
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 465118.802408
# Mean Squared Error: 216335500353.366821
# Mean Absolute Error: 398038.575048
# R² Score: -2.723518
# ----------
# Best Epoch (First Round): 60, Validation Loss: 216564105216.000000
# Best Epoch (Second Round): 30, Validation Loss: 216333762560.000000
#
#   Evaluating with optimizer: RMSprop
#
# Neural Network Metrics (ANN):
# Root Mean Square Error: 465334.067258
# Mean Squared Error: 216535794150.819305
# Mean Absolute Error: 398183.268342
# R² Score: -2.726966
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 465333.801052
# Mean Squared Error: 216535546401.309723
# Mean Absolute Error: 398181.618856
# R² Score: -2.726961
# ----------
# Best Epoch (First Round): 60, Validation Loss: 216659116032.000000
# Best Epoch (Second Round): 30, Validation Loss: 216535793664.000000
#
#   Evaluating with optimizer: Adagrad
#
# Neural Network Metrics (ANN):
# Root Mean Square Error: 465594.876642
# Mean Squared Error: 216778589154.912415
# Mean Absolute Error: 398348.006672
# R² Score: -2.731144
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 465594.996268
# Mean Squared Error: 216778700549.688751
# Mean Absolute Error: 398348.117009
# R² Score: -2.731146
# ----------
# Best Epoch (First Round): 60, Validation Loss: 
# ----------
# Best Epoch (First Round): 60, Validation Loss: 216759156736.000000
# Best Epoch (Second Round): 30, Validation Loss: 216741183488.000000
#
#
# ------------------------------------------------------
# Evaluating model: EcoCurrentNet_V4
#   Evaluating with optimizer: Adam
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 34065.422065
# Mean Squared Error: 1160452980.433837
# Mean Absolute Error: 25672.105945
# R² Score: 0.980027
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 16930.196170
# Mean Squared Error: 286631542.365147
# Mean Absolute Error: 12090.104110
# R² Score: 0.995067
# ----------
# Best Epoch (First Round): 50, Validation Loss: 1034143488.000000
# Best Epoch (Second Round): 2, Validation Loss: 1119099008.000000
#
#   Evaluating with optimizer: RMSprop
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 29797.208091
# Mean Squared Error: 887873610.015121
# Mean Absolute Error: 22843.745466
# R² Score: 0.984718
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 19555.970973
# Mean Squared Error: 382436000.714550
# Mean Absolute Error: 14593.846321
# R² Score: 0.993418
# ----------
# Best Epoch (First Round): 43, Validation Loss: 911225984.000000
# Best Epoch (Second Round): 26, Validation Loss: 836268416.000000
#
#   Evaluating with optimizer: Adagrad
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 451551.352373
# Mean Squared Error: 203898623829.751434
# Mean Absolute Error: 387223.889547
# R² Score: -2.509457
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 451370.281720
# Mean Squared Error: 203735131219.919769
# Mean Absolute Error: 387029.974411
# R² Score: -2.506643
# ----------
# Best Epoch (First Round): 60, Validation Loss: 209140416512.000000
# Best Epoch (Second Round): 30, Validation Loss: 203898617856.000000
#
#   Evaluating with optimizer: Adamax
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 38610.518541
# Mean Squared Error: 1490772142.011753
# Mean Absolute Error: 29413.641007
# R² Score: 0.974341
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 16546.806975
# Mean Squared Error: 273796821.078127
# Mean Absolute Error: 12756.178964
# R² Score: 0.995287
# ----------
# Best Epoch (First Round): 50, Validation Loss: 1532834560.000000
# Best Epoch (Second Round): 6, Validation Loss: 1471530752.000000
#
#   Evaluating with optimizer: Nadam
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 342842.655827
# Mean Squared Error: 117541086654.790192
# Mean Absolute Error: 299221.783912
# R² Score: -1.023091
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 341636.334363
# Mean Squared Error: 116715384956.646210
# Mean Absolute Error: 297732.723601
# R² Score: -1.008879
# ----------
# Best Epoch (First Round): 60, Validation Loss: 162700476416.000000
# Best Epoch (Second Round): 30, Validation Loss: 117541093376.000000
#
#   Evaluating with optimizer: Ftrl
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 463009.117960
# Mean Squared Error: 214377443314.248901
# Mean Absolute Error: 396303.406316
# R² Score: -2.689816
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 463005.481068
# Mean Squared Error: 214374075498.926025
# Mean Absolute Error: 396294.411378
# R² Score: -2.689758
# ----------
# Best Epoch (First Round): 60, Validation Loss: 215288922112.000000
# Best Epoch (Second Round): 30, Validation Loss: 214377447424.000000
#
#
# ------------------------------------------------------
# Evaluating model: EcoCurrentNet_V5
#   Evaluating with optimizer: Adam
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 459770.218930
# Mean Squared Error: 211388654215.088043
# Mean Absolute Error: 393068.222318
# R² Score: -2.638374
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 455630.760941
# Mean Squared Error: 207599390315.861237
# Mean Absolute Error: 389509.491635
# R² Score: -2.573154
# ----------
# Best Epoch (First Round): 60, Validation Loss: 213807398912.000000
# Best Epoch (Second Round): 30, Validation Loss: 211388645376.000000
#
#   Evaluating with optimizer: RMSprop
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 456542.418050
# Mean Squared Error: 208430979479.074585
# Mean Absolute Error: 390384.362205
# R² Score: -2.587467
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 450772.595882
# Mean Squared Error: 203195933198.417877
# Mean Absolute Error: 385324.937155
# R² Score: -2.497363
# ----------
# Best Epoch (First Round): 50, Validation Loss: 210174951424.000000
# Best Epoch (Second Round): 30, Validation Loss: 208430972928.000000
#
#   Evaluating with optimizer: Adagrad
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 417226.689010
# Mean Squared Error: 174078110022.420929
# Mean Absolute Error: 350793.942740
# R² Score: -1.996193
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 396890.475659
# Mean Squared Error: 157522049668.941437
# Mean Absolute Error: 333759.558742
# R² Score: -1.711234
# ----------
# Best Epoch (First Round): 58, Validation Loss: 194758213632.000000
# Best Epoch (Second Round): 30, Validation Loss: 174078099456.000000
#
#   Evaluating with optimizer: Adamax
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 465430.653943
# Mean Squared Error: 216625693629.372253
# Mean Absolute Error: 398188.262300
# R² Score: -2.728513
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 465412.490361
# Mean Squared Error: 216608786183.657898
# Mean Absolute Error: 398179.722911
# R² Score: -2.728222
# ----------
# Best Epoch (First Round): 60, Validation Loss: 216721326080.000000
# Best Epoch (Second Round): 30, Validation Loss: 216625692672.000000
#
#   Evaluating with optimizer: Nadam
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 382229.021511
# Mean Squared Error: 146099024885.139191
# Mean Absolute Error: 314039.659839
# R² Score: -1.514624
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 324273.738085
# Mean Squared Error: 105153457211.446167
# Mean Absolute Error: 268162.391395
# R² Score: -0.809878
# ----------
# Best Epoch (First Round): 54, Validation Loss: 142495285248.000000
# Best Epoch (Second Round): 13, Validation Loss: 143722561536.000000
#
#   Evaluating with optimizer: Ftrl
# c:\Users\Monet\anaconda3\envs\bone-age\lib\site-packages\keras\engine\functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)
# Neural Network Metrics (ANN):
# Root Mean Square Error: 460366.289374
# Mean Squared Error: 211937120392.164154
# Mean Absolute Error: 393636.520905
# R² Score: -2.647814
#
# CatBoost Metrics (CatBoost):
# Root Mean Square Error: 457904.069796
# Mean Squared Error: 209676137136.033508
# Mean Absolute Error: 391180.635011
# R² Score: -2.608899
# ----------
# Best Epoch (First Round): 60, Validation Loss: 214053175296.000000
# Best Epoch (Second Round): 27, Validation Loss: 211877265408.000000
#
#
# Model Evaluation Results:
# Model Name                     Optimizer       R² Score (CatBoost)
# ============================================================
# EcoCurrentNet_V4 - RMSprop: r2_catboost = 0.9847
# EcoCurrentNet_V4 - Adam: r2_catboost = 0.9800
# EcoCurrentNet_V4 - Adamax: r2_catboost = 0.9743
# EcoCurrentNet_V3 - Nadam: r2_catboost = 0.8066
# EcoCurrentNet_V3 - Adam: r2_catboost = 0.7635
# EcoCurrentNet_V3 - RMSprop: r2_catboost = 0.4275
# EcoCurrentNet_V3 - Adamax: r2_catboost = -0.0736
# EcoCurrentNet_V4 - Nadam: r2_catboost = -1.0231
# EcoCurrentNet_V5 - Nadam: r2_catboost = -1.5146
# EcoCurrentNet_V5 - Adagrad: r2_catboost = -1.9962
# EcoCurrentNet_V4 - Adagrad: r2_catboost = -2.5095
# EcoCurrentNet_V5 - RMSprop: r2_catboost = -2.5875
# EcoCurrentNet_V5 - Adam: r2_catboost = -2.6384
# EcoCurrentNet_V5 - Ftrl: r2_catboost = -2.6478
# EcoCurrentNet_V4 - Ftrl: r2_catboost = -2.6898
# EcoCurrentNet_V2 - Adam: r2_catboost = -2.7198
# EcoCurrentNet_V2 - Nadam: r2_catboost = -2.7227
# EcoCurrentNet_V1 - Adam: r2_catboost = -2.7235
# EcoCurrentNet_V1 - Nadam: r2_catboost = -2.7235
# EcoCurrentNet_V3 - Adagrad: r2_catboost = -2.7241
# EcoCurrentNet_V1 - RMSprop: r2_catboost = -2.7270
# EcoCurrentNet_V2 - RMSprop: r2_catboost = -2.7280
# EcoCurrentNet_V5 - Adamax: r2_catboost = -2.7285
# EcoCurrentNet_V1 - Adamax: r2_catboost = -2.7288
# EcoCurrentNet_V2 - Adamax: r2_catboost = -2.7294
# EcoCurrentNet_V3 - Ftrl: r2_catboost = -2.7305
# EcoCurrentNet_V1 - Ftrl: r2_catboost = -2.7311
# EcoCurrentNet_V1 - Adagrad: r2_catboost = -2.7311
# EcoCurrentNet_V2 - Adagrad: r2_catboost = -2.7312
# EcoCurrentNet_V2 - Ftrl: r2_catboost = -2.7312

# %%
end_time = datetime.now()
print("Code running ended at:", end_time.strftime("%Y-%m-%d %H:%M:%S"))
print("---------------------------------------")

execution_time = end_time - start_time
print("Total execution time:", execution_time)
# Out:
# Code running ended at: 2024-10-29 12:18:42
# ---------------------------------------
# Total execution time: 0:10:31.158755
